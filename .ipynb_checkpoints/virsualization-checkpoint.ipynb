# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./log.csv')
df.plot(x="generation", y=["avarage fitness", "global best fitness", "local best fitness"])
df
# Out:
#      generation  avarage fitness  local best fitness  global best fitness  \
# 0           1.0             1.54                3.50                 3.50
# 1           2.0             1.68                3.43                 3.50
# 2           3.0             1.76                3.62                 3.62
# 3           4.0             1.81                3.33                 3.62
# 4           5.0             1.90                5.33                 5.33
# ..          ...              ...                 ...                  ...
# 495       496.0            29.40               30.00                34.00
# 496       497.0            29.40               30.00                34.00
# 497       498.0            29.43               30.00                34.00
# 498       499.0            29.45               30.00                34.00
# 499       500.0            29.44               30.00                34.00
#
#      h-h pairs of best candidate  overlapped pairs of best candidate
# 0                           21.0                                 5.0
# 1                           21.0                                 5.0
# 2                           47.0                                12.0
# 3                           47.0                                12.0
# 4                           16.0                                 2.0
# ..                           ...                                 ...
# 495                         34.0                                 0.0
# 496                         34.0                                 0.0
# 497                         34.0                                 0.0
# 498                         34.0                                 0.0
# 499                         34.0                                 0.0
#
# [500 rows x 6 columns]

# %%
df_16 = pd.read_csv('./data/SEQ50_16.csv')
df_16.plot(x="generation", y=["avarage fitness", "global best fitness", "local best fitness"])
# Out:
# <Axes: xlabel='generation'>
